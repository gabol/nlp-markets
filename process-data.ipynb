# %% [markdown]
# ## Setup

# %%
import pandas as pd
import matplotlib as plt
import urllib3

# %% [markdown]
# ## Gather Data

# %%
nasdaq_url = "https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=nasdaq&render=download"
nyse_url = "https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=amex&render=download"
amex_url = "https://old.nasdaq.com/screening/companies-by-name.aspx?letter=0&exchange=amex&render=download"

# %% [markdown]
# ### This approach uses pandas and is simpler and more readable, but the csv has to be stored in memory.

# %%
test = pd.read_csv("http://spatialkeydocs.s3.amazonaws.com/FL_insurance_sample.csv.zip", header=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-7c2197186bdf> in <module>
# ----> 1 test = pd.read_csv("http://spatialkeydocs.s3.amazonaws.com/FL_insurance_sample.csv.zip", header=None)
#
# /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
# ...

# %%
medals_url = "http://spatialkeydocs.s3.amazonaws.com/FL_insurance_sample.csv"
http = urllib3.PoolManager()
r = http.request("GET", medals_url)
r.status

data = "".join(map(chr,r.data))
print(data)
data = data.split('\n')
for row in data:
    print(row)
# Out:
# èË4589þ¹ÝÒñÕÃ~½ZaPiúþÓ0æÖYÖ]õwóÚXä±¶X¬úó8ru{XQîYæ¸5eºÛéYòn#5¬áJU6Îª/´B:9'Ïìî±ÆèKSô`{n¾ëJÊ2¶Eu|Î`¥:]û¦îáËqf0ÜD+ÂÇs|hEu[,5fQIÙûçÅÒWßkèõÜ	çEg«ëvÖDzõªÎ%yv2Æ5!ÃRÝÍ'L9ä,×K<àoêñP,¾~MJ¸»¾DÑ89UA ÝQt_
# JPÿIqíKÂÿo+²$3]ÃsågY&¶×MX
# ×¾ì.S^¬Ï¿¥
# ßK9tï	;"KÿeJ¬/&ñImAkMªÙNá-
# il²ýnDýs/ò©Ø³ZÌ}ÅÓ¼YCeýG(q¢]ð9jUTö2YYðz*
# öy¬iudaé©ÆN×¾L»JÛýßMØ£/S3b®hoU</ÓÙ1ÓÿÂà\YG û­ÃY&ò9eB^S/^ï%tGÔ}+æäs~ïsæ¡c¿µ/½ú$ªÁÔwgíaYÃxÊ÷Xo¨­Á0eB=_ý­gjR±c7E¦¼ï68Îå6ÛcXàú*t§õÒEÅW#ç´â #&ôíV±ûðYGHD GdÁþKÌáÍZÎ©[8Å}¿Á§díÁJ$lFÿÿI{×]kzæ8ì
# yÆQs\lÑÅ'%ÏÖê¨°cÏeSFPå2Åï­6%/éL#
# ...
